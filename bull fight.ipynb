# %%
import numpy as np
import re
from itertools import combinations
from tqdm import tqdm
import pandas as pd
from collections import Counter
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import stats

# %%
def xipai(x):
    """
    'xipai' means shuffling the decks in chinese
    """
    for _ in range(100):
        np.random.shuffle(x)
    return x

def initialization():
    """
    This function is to initialize the decks everytime we start playing
    """
    original_state = []
    for ii in np.arange(1,10):
        for jj in ['a','b','c','d']:
            original_state.append('{}{}'.format(ii,jj))
    original_state = np.array(original_state,dtype=str)
    return original_state

def check(play):
    """
    This function is to check the cards of one single player and get all possible bull and base combinations
    if there exist these bulls and bases, we save them, 
    but if there does not exist any bull or base, we return an empty list
    """
    bases,bulls = [],[]
    for t in combinations(play,3):
        if np.sum([int(re.findall('\d+',item)[0]) for item in t]) % 10 == 0:
            bases_ = [ii for ii in t]
            bulls_ = [ii for ii in play if ii not in list(t)]
            if len(bulls_) > 0:
                bulls.append(bulls_)
                bases.append(bases_)
    return bulls,bases

def get_points(bull):
    """
    if there exists any bulls and bases, we calculate the points
    if the sum of the bull cards is greater than 10, we subtract 10
    if there does not exist any bull or base, point is 0
    """
    bulls,bases = check(bull)
    if len(bull) > 0:
        points = np.sum(int(re.findall('\d+',ii)[0]) for ii in bull) 
        if points > 10:
            points = points - 10
    else:
        points = 0
        
    return points

def get_bull_base(play):
    """
    since whichever combination of bulls and bases does not matter, we just pick one if there are more than one
    or, that is empty
    """
    bulls,bases = check(play)
    if len(bases) < 1:
        bull,base = [],[]
    elif len(bases) > 1:
        pick = np.random.choice(len(bases),size=1)[0]
        bull,base = bulls[pick],bases[pick]
    else:
        bull,base = bulls[0],bases[0]
    return bull,base

def win_lose(players,zhuang='player1',xian='player2'):
    """
    To determine winning or losing, we need to compare 2 players: zhuang and xian
    each round, we have one zhuang and the others are xian
    if zhuang wins, zhuang wins against individual xian
    but if xian wins, xian wins the points xian gets
    """
    letter2num = {'a':4,'b':3,'c':2,'d':1}
    bull1,base1 = get_bull_base(players[zhuang])
    bull2,base2 = get_bull_base(players[xian])
    #print(bull1,bull2)
    
    point1 = np.sum(int(re.findall('\d+',ii)[0]) for ii in bull1)
    point2 = np.sum(int(re.findall('\d+',ii)[0]) for ii in bull2)
    
    if point1 > point2:
        return -(point1 - point2)
    elif point1 < point2:
        return point2 - point1
    elif point1 == point2:
        cards1 = [int(re.findall('\d+',ii)[0]) for ii in players[zhuang]]
        color1 = [ii[1] for ii in players[zhuang]]
        cards2 = [int(re.findall('\d+',ii)[0]) for ii in players[xian]]
        color2 = [ii[1] for ii in players[xian]]
        
        if np.max(cards1) > np.max(cards2):
            return -(np.max(cards1) - np.max(cards2))
        elif np.max(cards1) < np.max(cards2):
            return np.max(cards2) - np.max(cards1)
        elif np.max(cards1) == np.max(cards2):
            idx1 = np.argmax(cards1)
            idx2 = np.argmax(cards2)
            
            c1 = color1[idx1]
            c2 = color2[idx2]
            
            if letter2num[c1] > letter2num[c2]:
                return -np.max(cards1)
            elif letter2num[c1] < letter2num[c2]:
                return np.max(cards2)

# %% [markdown]
# # Let's play the game 100 times and play these 100 times over 1000 nights

# %%
wins = {'player{}'.format(ii):[] for ii in np.arange(1,8)}
being = {'player{}'.format(ii):[] for ii in np.arange(1,8)}
for sim in tqdm(range(int(1e1))):
    zhuang = 'player1'
    next_zhuang = 'player1'
    cc = {'player{}'.format(ii):[] for ii in np.arange(1,8)}
    cc['zhuang']=[]
    for round_ in range(int(1e2)):
        original_state = initialization()

        shuffled_state = xipai(original_state)
        left = shuffled_state[-1]
        shuffled_state = shuffled_state[:-1].reshape(-1,5)
        shuffled_state
        players = {'player{}'.format(ii+1):row for ii,row in enumerate(shuffled_state)}

        #print(players,'\nleft out: {}'.format(left))



        [cc[player].append(get_bull_base(row)) for player,row in players.items()]
        for player,play in players.items():
            bull,base = get_bull_base(play)
            point = get_points(bull)
            if point == 10:
                next_zhuang = player
        cc['zhuang'].append(zhuang)
        zhuang = next_zhuang
# Out:
# 100%|██████████████████████████████████████████| 10/10 [00:03<00:00,  3.37it/s]

# %%
cc = pd.DataFrame(cc)

# %%
cc.columns
# Out:
# Index(['player1', 'player2', 'player3', 'player4', 'player5', 'player6',
#        'player7', 'zhuang'],
#       dtype='object')

# %%
results = {'player{}'.format(ii):[] for ii in np.arange(1,8)}
results['zhuang'] = []
for ii, row in cc.iterrows():
    zhuang = row[row['zhuang']]
    xian = [row[player] for player in cc.columns[:-1] if (player != row['zhuang'])]
    
    point_z = get_points(zhuang[0])
    
    if point_z == 10:
        results[row['zhuang']].append(6 * 10)
        [results[player].append(-10) for player in cc.columns[:-1] if (player != row['zhuang'])]
        results['zhuang'].append(row['zhuang'])
    elif point_z == 0:
        scores = [0 - get_points(row[player][0]) for player in cc.columns[:-1] if (player != row['zhuang'])]
        results[row['zhuang']].append(np.sum(scores))
        [results[player].append(get_points(row[player][0])) for player in cc.columns[:-1] if (player != row['zhuang'])]
        results['zhuang'].append(row['zhuang'])
    else:
        scores = [point_z - get_points(row[player][0]) for player in cc.columns[:-1] if (player != row['zhuang'])]
        results[row['zhuang']].append(np.sum(scores))
        [results[player].append(get_points(row[player][0])) for player in cc.columns[:-1] if (player != row['zhuang'])]
        results['zhuang'].append(row['zhuang'])

# %%
cc
# Out:
#                      player1                   player2  \
# 0                   ([], [])                  ([], [])
# 1                   ([], [])                  ([], [])
# 2   ([8d, 2b], [9b, 4a, 7c])                  ([], [])
# 3   ([5a, 1b], [9c, 3b, 8b])  ([8d, 7c], [1a, 6a, 3c])
# 4                   ([], [])                  ([], [])
# 5                   ([], [])  ([3a, 7c], [4b, 5c, 1b])
# 6   ([6c, 3d], [8b, 8d, 4b])  ([7c, 5c], [6b, 5d, 9a])
# 7                   ([], [])  ([5a, 1c], [8c, 8a, 4d])
# 8   ([4d, 7b], [3c, 5a, 2a])  ([7a, 6d], [3d, 5d, 2c])
# 9   ([5d, 6b], [9a, 8c, 3a])                  ([], [])
# 10  ([6b, 4c], [9d, 3b, 8a])  ([7d, 7c], [3c, 1d, 6c])
# 11  ([7b, 2c], [6c, 7d, 7a])  ([3c, 4a], [5a, 9d, 6a])
# 12                  ([], [])                  ([], [])
# 13  ([2a, 6d], [9a, 7d, 4b])  ([1d, 1c], [4d, 3b, 3a])
# 14  ([1a, 3b], [9a, 4b, 7b])  ([8a, 2a], [5c, 7d, 8d])
# 15  ([9c, 8d], [2c, 2a, 6c])  ([3c, 7b], [2d, 1c, 7d])
# 16  ([9a, 3d], [5c, 7a, 8d])  ([5d, 6b], [2c, 1c, 7d])
# 17  ([2a, 1a], [8b, 5d, 7c])  ([9c, 1c], [4b, 4c, 2b])
# 18                  ([], [])                  ([], [])
# 19  ([5d, 5a], [3a, 1a, 6d])                  ([], [])
# 20  ([6a, 7b], [7a, 8c, 5d])                  ([], [])
# 21  ([1d, 9c], [2d, 5c, 3a])  ([6d, 5d], [4a, 2b, 4d])
# 22  ([9a, 8c], [2a, 6b, 2d])  ([5b, 1a], [5c, 2b, 3a])
# 23                  ([], [])  ([6b, 5b], [8d, 3b, 9a])
# 24  ([8d, 3c], [7a, 6b, 7d])                  ([], [])
# 25  ([3a, 8a], [5b, 7b, 8c])  ([4b, 7c], [8b, 5d, 7a])
# 26  ([4a, 2c], [6c, 5b, 9a])                  ([], [])
# 27  ([7c, 9c], [6b, 9b, 5d])  ([1c, 5a], [6c, 3d, 1a])
# 28  ([6a, 4a], [6b, 1d, 3a])  ([4c, 4d], [6d, 5c, 9a])
# 29                  ([], [])  ([1d, 5c], [9b, 7a, 4b])
# ..                       ...                       ...
# 70  ([7c, 6b], [2d, 2c, 6c])                  ([], [])
# 71                  ([], [])  ([8a, 1a], [4d, 3d, 3c])
# 72                  ([], [])  ([5d, 9c], [7a, 1c, 2a])
# 73                  ([], [])                  ([], [])
# 74  ([3c, 4c], [2c, 9b, 9c])                  ([], [])
# 75  ([3a, 9b], [4b, 5d, 1a])  ([2a, 8b], [5b, 4c, 1c])
# 76                  ([], [])  ([4c, 9b], [2d, 5c, 3a])
# 77  ([8c, 8d], [2c, 5c, 3b])  ([9c, 2d], [6c, 1a, 3a])
# 78                  ([], [])                  ([], [])
# 79  ([2b, 9d], [5b, 2c, 3c])  ([1d, 1b], [4d, 5c, 1a])
# 80  ([7c, 3a], [1b, 1a, 8c])  ([8d, 9c], [4b, 4c, 2a])
# 81  ([9a, 3b], [8b, 4b, 8c])                  ([], [])
# 82  ([8b, 7c], [7a, 2b, 1c])  ([3b, 4c], [2a, 2c, 6c])
# 83  ([3b, 5b], [9c, 3c, 8c])  ([2a, 8a], [8d, 3d, 9b])
# 84                  ([], [])  ([6a, 6d], [5d, 4c, 1a])
# 85                  ([], [])  ([8c, 8b], [1b, 7d, 2a])
# 86  ([1c, 6d], [2a, 4c, 4a])  ([7a, 6b], [3c, 1d, 6c])
# 87                  ([], [])                  ([], [])
# 88  ([5a, 7c], [2a, 2d, 6b])  ([4c, 8b], [6a, 1d, 3d])
# 89  ([1d, 4c], [8b, 6c, 6d])                  ([], [])
# 90                  ([], [])  ([5d, 4a], [6a, 2a, 2c])
# 91  ([2d, 8b], [5c, 9a, 6b])                  ([], [])
# 92  ([8d, 6a], [4c, 8a, 8c])  ([9d, 3a], [1b, 2c, 7c])
# 93  ([8c, 1c], [7b, 7d, 6b])  ([4d, 4c], [1a, 6c, 3b])
# 94                  ([], [])                  ([], [])
# 95  ([8d, 4b], [5b, 3c, 2c])  ([5c, 7d], [7a, 1a, 2d])
# 96  ([8d, 2d], [6d, 9d, 5d])                  ([], [])
# 97  ([3b, 4a], [3a, 9b, 8a])  ([3d, 1b], [7b, 9a, 4b])
# 98                  ([], [])  ([2c, 3d], [4c, 8a, 8c])
# 99                  ([], [])  ([4b, 5a], [4a, 7c, 9d])
#
#                      player3                   player4  \
# 0                   ([], [])  ([4a, 5a], [1d, 3a, 6a])
# 1                   ([], [])                  ([], [])
# 2   ([8c, 1c], [3d, 5c, 2c])  ([4c, 6a], [3c, 5d, 2d])
# 3                   ([], [])                  ([], [])
# 4                   ([], [])                  ([], [])
# 5   ([2d, 9c], [9b, 8b, 3b])  ([1a, 4d], [4a, 9a, 7b])
# 6   ([4a, 3a], [6d, 5b, 9b])                  ([], [])
# 7   ([5d, 6b], [3a, 4b, 3d])  ([7b, 8b], [6d, 9d, 5c])
# 8   ([6b, 4c], [2d, 7d, 1a])  ([9a, 9c], [1c, 4b, 5b])
# 9                   ([], [])  ([3c, 4c], [1d, 2d, 7a])
# 10  ([5d, 5a], [3a, 6a, 1a])                  ([], [])
# 11  ([1d, 9a], [4d, 8d, 8b])  ([5d, 2a], [1a, 1c, 8c])
# 12  ([1c, 1b], [5c, 9c, 6d])  ([7b, 8b], [4d, 2b, 4b])
# 13  ([9b, 9c], [8b, 5d, 7a])  ([1b, 8c], [6c, 7c, 7b])
# 14                  ([], [])                  ([], [])
# 15  ([6a, 9a], [1b, 8c, 1d])                  ([], [])
# 16                  ([], [])                  ([], [])
# 17  ([6c, 6b], [5c, 7b, 8d])  ([8a, 3a], [5a, 3c, 2d])
# 18  ([7c, 2b], [1b, 3b, 6a])  ([9a, 5b], [4b, 4c, 2d])
# 19  ([6a, 9a], [8b, 8c, 4c])  ([3d, 6c], [4b, 8a, 8d])
# 20  ([5a, 5c], [2c, 7c, 1c])                  ([], [])
# 21  ([9d, 1c], [5a, 8a, 7c])  ([8b, 3c], [2c, 2a, 6a])
# 22                  ([], [])  ([4a, 6d], [4b, 9b, 7d])
# 23  ([5a, 3a], [2b, 1d, 7c])                  ([], [])
# 24  ([6c, 5b], [1b, 8a, 1d])  ([6a, 2b], [7c, 9a, 4b])
# 25  ([3b, 9a], [9d, 2b, 9c])  ([1c, 9b], [3d, 6a, 1d])
# 26  ([3b, 9c], [1c, 2d, 7b])  ([3a, 2b], [5c, 4c, 1a])
# 27  ([2a, 9a], [6a, 7d, 7b])                  ([], [])
# 28  ([2a, 9c], [8d, 7d, 5d])  ([3d, 4b], [2c, 7b, 1a])
# 29                  ([], [])                  ([], [])
# ..                       ...                       ...
# 70  ([7b, 1b], [9b, 5d, 6d])  ([5a, 4c], [9c, 4b, 7d])
# 71  ([4b, 2d], [9c, 4c, 7c])                  ([], [])
# 72  ([7c, 9d], [3a, 5b, 2d])                  ([], [])
# 73                  ([], [])  ([5d, 4c], [7a, 2d, 1d])
# 74  ([8b, 1c], [8a, 6c, 6b])                  ([], [])
# 75  ([4d, 1d], [6b, 7a, 7d])  ([2d, 7b], [3c, 8a, 9a])
# 76  ([8b, 3c], [1a, 7a, 2c])  ([5a, 2b], [8c, 6a, 6b])
# 77  ([9b, 6a], [4c, 5d, 1b])  ([7c, 8b], [9a, 6d, 5a])
# 78  ([3b, 9a], [7a, 7c, 6d])                  ([], [])
# 79  ([8d, 7b], [4b, 7a, 9c])  ([9b, 6d], [8a, 5d, 7d])
# 80  ([5c, 7b], [9b, 8b, 3c])                  ([], [])
# 81  ([2d, 4a], [2c, 5a, 3c])  ([4d, 1a], [7a, 7b, 6d])
# 82  ([8c, 6a], [5a, 1a, 4b])                  ([], [])
# 83  ([5d, 1c], [2c, 2b, 6d])  ([8b, 9d], [4d, 1b, 5c])
# 84  ([6b, 4a], [3b, 8a, 9d])                  ([], [])
# 85  ([8a, 1c], [2b, 9c, 9b])                  ([], [])
# 86  ([6a, 7d], [5a, 3b, 2b])  ([1a, 1b], [9c, 2d, 9a])
# 87  ([2a, 5c], [3c, 3d, 4d])  ([5a, 6c], [2b, 3b, 5b])
# 88                  ([], [])  ([7a, 9c], [4d, 8a, 8d])
# 89                  ([], [])                  ([], [])
# 90  ([9b, 8b], [1c, 3d, 6d])  ([9d, 5c], [3a, 5a, 2d])
# 91  ([2a, 4a], [8d, 1c, 1a])                  ([], [])
# 92  ([2d, 3d], [9a, 4b, 7b])                  ([], [])
# 93                  ([], [])                  ([], [])
# 94  ([1c, 8c], [5b, 6a, 9c])                  ([], [])
# 95                  ([], [])  ([9b, 6d], [7c, 4a, 9c])
# 96  ([7d, 2a], [9c, 6a, 5b])  ([8c, 4c], [2c, 3b, 5c])
# 97                  ([], [])  ([2b, 6d], [8b, 7d, 5c])
# 98  ([1b, 9c], [3a, 2a, 5a])  ([1a, 5b], [7d, 7c, 6b])
# 99  ([1d, 7b], [6a, 5b, 9b])                  ([], [])
#
#                      player5                   player6  \
# 0                   ([], [])                  ([], [])
# 1   ([9c, 1a], [6a, 6b, 8a])                  ([], [])
# 2                   ([], [])  ([6c, 7a], [5a, 2a, 3a])
# 3   ([9b, 3a], [4b, 5c, 1c])                  ([], [])
# 4                   ([], [])                  ([], [])
# 5   ([9d, 4c], [3c, 1c, 6a])  ([2a, 6b], [5b, 7a, 8d])
# 6   ([6a, 1b], [2b, 1a, 7b])  ([3c, 4d], [7a, 1c, 2a])
# 7   ([8d, 1b], [9c, 9b, 2d])  ([3c, 1d], [4a, 7c, 9a])
# 8                   ([], [])  ([2b, 1b], [4a, 5c, 1d])
# 9   ([1a, 8d], [9d, 5b, 6c])  ([9b, 5c], [2b, 7b, 1c])
# 10                  ([], [])  ([4a, 9c], [2b, 2c, 6d])
# 11                  ([], [])  ([7c, 1b], [3a, 2d, 5b])
# 12  ([7a, 8d], [3d, 8a, 9a])                  ([], [])
# 13                  ([], [])                  ([], [])
# 14  ([8b, 1c], [9b, 9d, 2b])                  ([], [])
# 15                  ([], [])  ([3a, 4b], [3b, 9d, 8a])
# 16  ([8a, 2a], [8b, 9d, 3a])  ([2d, 6c], [5b, 1b, 4d])
# 17                  ([], [])  ([2c, 6d], [7a, 7d, 6a])
# 18  ([4a, 3c], [2a, 9d, 9b])  ([7b, 7a], [6b, 1a, 3d])
# 19  ([1d, 1c], [7d, 4d, 9b])  ([9d, 1b], [3b, 2c, 5c])
# 20  ([5b, 9b], [1b, 6d, 3b])  ([4a, 4b], [8d, 3a, 9d])
# 21  ([7b, 9b], [4b, 5b, 1a])  ([9a, 8c], [4c, 3d, 3b])
# 22  ([9d, 5a], [8d, 7c, 5d])                  ([], [])
# 23  ([1c, 5c], [6d, 2a, 2c])  ([5d, 3d], [6a, 7a, 7d])
# 24  ([5a, 3d], [9c, 2a, 9b])  ([8c, 3b], [7b, 1c, 2d])
# 25  ([5c, 4d], [3c, 5a, 2c])  ([6d, 8d], [2d, 2a, 6b])
# 26  ([8b, 8d], [1d, 8c, 1b])  ([5d, 3d], [4b, 9d, 7d])
# 27  ([3a, 1b], [4b, 2b, 4c])                  ([], [])
# 28  ([9d, 1c], [8b, 9b, 3c])  ([8c, 8a], [2b, 7c, 1b])
# 29                  ([], [])  ([3d, 5d], [2b, 6a, 2c])
# ..                       ...                       ...
# 70  ([3c, 9a], [7a, 2b, 1c])                  ([], [])
# 71  ([8b, 2c], [1d, 2b, 7a])  ([3a, 6b], [5b, 7b, 8c])
# 72                  ([], [])  ([4a, 3d], [7d, 8a, 5a])
# 73  ([5a, 4a], [9d, 8c, 3b])  ([7d, 1a], [6d, 1c, 3d])
# 74                  ([], [])  ([4d, 4b], [9d, 5d, 6a])
# 75  ([8c, 5c], [5a, 6d, 9c])  ([8d, 4a], [1b, 6a, 3b])
# 76                  ([], [])                  ([], [])
# 77  ([5b, 7d], [1c, 3c, 6b])  ([2a, 8a], [2b, 4b, 4a])
# 78  ([9c, 1a], [5c, 4a, 1b])  ([7b, 5b], [9b, 9d, 2d])
# 79  ([2a, 7c], [8c, 6a, 6c])  ([4a, 5a], [3d, 9a, 8b])
# 80  ([8a, 9a], [2d, 6b, 2c])                  ([], [])
# 81  ([4c, 2b], [8a, 3a, 9b])  ([5d, 1c], [1b, 7c, 2a])
# 82  ([1b, 3c], [9a, 8a, 3d])                  ([], [])
# 83                  ([], [])  ([5a, 3a], [7b, 6c, 7d])
# 84  ([8d, 3c], [8c, 5c, 7a])                  ([], [])
# 85  ([4c, 8d], [4a, 4b, 2c])                  ([], [])
# 86  ([9d, 8c], [8a, 7c, 5c])                  ([], [])
# 87                  ([], [])  ([9d, 2c], [5d, 7d, 8c])
# 88  ([4a, 5c], [2c, 1a, 7b])                  ([], [])
# 89  ([9c, 2c], [2d, 1a, 7c])  ([3c, 9a], [4a, 1b, 5b])
# 90                  ([], [])                  ([], [])
# 91  ([6a, 7b], [9c, 3d, 8c])  ([9b, 3c], [4b, 5a, 1d])
# 92                  ([], [])  ([2a, 9c], [3b, 1a, 6b])
# 93  ([1b, 9b], [5c, 3d, 2d])  ([1d, 7a], [6d, 9a, 5d])
# 94  ([5d, 6d], [7c, 4c, 9a])                  ([], [])
# 95  ([7b, 2a], [6b, 8a, 6c])  ([1b, 8b], [1c, 4c, 5d])
# 96  ([8a, 3a], [9a, 6b, 5a])  ([7a, 1a], [8b, 9b, 3d])
# 97  ([6b, 1a], [5a, 7a, 8d])  ([5b, 5d], [6c, 2d, 2c])
# 98                  ([], [])  ([6c, 7a], [9a, 3b, 8b])
# 99                  ([], [])  ([2a, 8c], [1c, 6b, 3b])
#
#                      player7   zhuang
# 0                   ([], [])  player1
# 1   ([3d, 7a], [4a, 4c, 2a])  player1
# 2                   ([], [])  player7
# 3                   ([], [])  player4
# 4   ([5c, 9d], [2b, 1c, 7d])  player4
# 5   ([8c, 8a], [2c, 6d, 2b])  player4
# 6   ([4c, 1d], [9c, 8a, 3b])  player2
# 7   ([3b, 6c], [1a, 7a, 2c])  player2
# 8   ([8b, 3a], [6c, 6a, 8c])  player2
# 9   ([1b, 9c], [5a, 3b, 2a])  player3
# 10                  ([], [])  player7
# 11  ([9c, 3d], [9b, 5c, 6b])  player3
# 12  ([3c, 5a], [7d, 6b, 7c])  player3
# 13                  ([], [])  player3
# 14  ([1b, 4d], [7c, 2c, 1d])  player3
# 15                  ([], [])  player2
# 16                  ([], [])  player2
# 17  ([4a, 1b], [4d, 3d, 3b])  player5
# 18  ([8d, 3a], [6d, 5d, 9c])  player2
# 19  ([7a, 9c], [2d, 2b, 6b])  player2
# 20  ([6b, 6c], [8b, 3d, 9c])  player6
# 21  ([7a, 1b], [8d, 6c, 6b])  player3
# 22                  ([], [])  player3
# 23  ([6c, 4c], [7b, 1a, 2d])  player4
# 24  ([9d, 2c], [3a, 6d, 1a])  player7
# 25                  ([], [])  player7
# 26  ([7a, 4d], [8a, 3c, 9b])  player4
# 27  ([1d, 8d], [3c, 8a, 9d])  player4
# 28                  ([], [])  player4
# 29                  ([], [])  player5
# ..                       ...      ...
# 70                  ([], [])  player4
# 71                  ([], [])  player4
# 72  ([2b, 3c], [8d, 1d, 1a])  player5
# 73                  ([], [])  player5
# 74  ([8c, 7d], [3b, 1d, 6d])  player5
# 75                  ([], [])  player5
# 76                  ([], [])  player2
# 77                  ([], [])  player2
# 78                  ([], [])  player6
# 79  ([2d, 1c], [3b, 4c, 3a])  player5
# 80  ([3b, 3d], [9d, 7a, 4d])  player5
# 81  ([9c, 3d], [5c, 9d, 6c])  player1
# 82  ([9b, 4d], [3a, 8d, 9d])  player1
# 83                  ([], [])  player1
# 84  ([9a, 5b], [1d, 6c, 3d])  player2
# 85  ([6b, 3d], [7a, 7b, 6d])  player3
# 86  ([4d, 2c], [8b, 9b, 3d])  player3
# 87                  ([], [])  player3
# 88  ([1b, 9d], [3b, 5d, 2b])  player3
# 89                  ([], [])  player7
# 90                  ([], [])  player7
# 91  ([7a, 2b], [6d, 5d, 9d])  player7
# 92  ([4d, 9b], [8b, 7a, 5d])  player1
# 93  ([5a, 3a], [9d, 4b, 7c])  player1
# 94                  ([], [])  player5
# 95                  ([], [])  player5
# 96  ([4d, 6c], [2b, 7b, 1d])  player5
# 97  ([8c, 6a], [9d, 2a, 9c])  player7
# 98  ([1d, 4a], [3c, 9b, 8d])  player6
# 99  ([8d, 6c], [5d, 4d, 1b])  player3
#
# [100 rows x 8 columns]

# %%
pd.DataFrame(results)
# Out:
#     player1  player2  player3  player4  player5  player6  player7   zhuang
# 0        -9        0        0        9        0        0        0  player1
# 1       -20        0        0        0       10        0       10  player1
# 2        10        0        9       10        0        3      -32  player7
# 3         6        5        0      -13        2        0        0  player4
# 4         0        0        0       -4        0        0        4  player4
# 5         0       10        1        2        3        8        6  player4
# 6         9      -23        7        0        7        7        5  player2
# 7         0        8        1        5        9        4        9  player2
# 8         1       -5       10        8        0        3        1  player2
# 9         1        0      -31        7        9        4       10  player3
# 10       10        4       10        0        0        3      -27  player7
# 11      -10      -10       60      -10      -10      -10      -10  player3
# 12        0        0       -6        5        5        0        8  player3
# 13        8        2       29        9        0        0        0  player3
# 14        4       10      -28        0        9        0        5  player3
# 15      -10       60      -10      -10      -10      -10      -10  player2
# 16        2      -14        0        0       10        8        0  player2
# 17        3       10        2        1      -29        8        5  player5
# 18        0      -25        9        4        7        4        1  player2
# 19       10      -42        5        9        2       10        6  player2
# 20        3        0       10        0        4       29        2  player6
# 21      -10      -10       60      -10      -10      -10      -10  player3
# 22        7        6      -27       10        4        0        0  player3
# 23        0        1        8      -33        6        8       10  player4
# 24        1        0        1        8        8        1      -13  player7
# 25        1        1        2       10        9        4      -27  player7
# 26        6        0        2        7        6        8        1  player4
# 27        6        6        1      -26        4        0        9  player4
# 28       10        8        1        7       10        6        0  player4
# 29        0        6        0        0      -14        8        0  player5
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 70        3        0        8       41        2        0        0  player4
# 71        0        9        6      -34       10        9        0  player4
# 72        0        4        6        0      -22        7        5  player5
# 73        0        0        0        9       37        8        0  player5
# 74        7        0        9        0      -29        8        5  player5
# 75        2       10        5        9      -10        2        0  player5
# 76        0       10        1        7        0        0        0  player2
# 77        6      -22        5        5        2       10        0  player2
# 78        0        0        2        0       10        0        0  player6
# 79        1        2        5        5       29        9        3  player5
# 80       10        7        2        0       17        0        6  player5
# 81      -13        0        6        5        6        6        2  player1
# 82       12        7        4        0        4        0        3  player1
# 83       17       10        6        7        0        8        0  player1
# 84        0       -3       10        0        1        0        4  player2
# 85        0        6       37        0        2        0        9  player3
# 86        7        3       -7        2        7        0        6  player3
# 87        0        0       40        1        0        1        0  player3
# 88        2        2      -29        6        9        0       10  player3
# 89        5        0        0        0        1        2       -8  player7
# 90        0        9        7        4        0        0      -20  player7
# 91       10        0        6        0        3        2       33  player7
# 92       13        2        5        0        0        1        3  player1
# 93       20        8        0        0       10        8        8  player1
# 94        0        0        9        0       -3        0        0  player5
# 95        2        2        0        5       36        9        0  player5
# 96       10        0        9        2      -33        8       10  player5
# 97        7        4        0        8        7       10      -12  player7
# 98        0        5       10        6        0       -8        5  player6
# 99        0        9       25        0        0       10        4  player3
#
# [100 rows x 8 columns]

# %% [markdown]
# # After the simulation, we could correlate the number of winnings and the number of being zhuang, and it should be somewhat consistent

# %%
for player in wins.keys():
    print(player,stats.spearmanr(wins[player],being[player]))
# Out:
# player1 SpearmanrResult(correlation=0.38905954795524134, pvalue=0.2664779212005221)
# player2 SpearmanrResult(correlation=-0.08510677611520905, pvalue=0.8151715445415288)
# player3 SpearmanrResult(correlation=0.7112494861056756, pvalue=0.021090925985548795)
# player4 SpearmanrResult(correlation=0.8997002046464955, pvalue=0.00039167359562948393)
# player5 SpearmanrResult(correlation=0.7963562622208846, pvalue=0.005836997302932195)
# player6 SpearmanrResult(correlation=0.790277206784084, pvalue=0.006514223587240812)
# player7 SpearmanrResult(correlation=0.9636363636363635, pvalue=7.320974809529922e-06)

# %%
pd.DataFrame(cc)
# Out:
#                      player1                   player2  \
# 0   ([3d, 4b], [2b, 6a, 2c])  ([2a, 2d], [4c, 8d, 8c])
# 1                   ([], [])  ([3c, 1d], [4c, 8d, 8a])
# 2   ([7a, 3c], [7c, 9a, 4a])  ([1d, 4d], [4b, 7d, 9d])
# 3                   ([], [])  ([5c, 3d], [4d, 7c, 9a])
# 4                   ([], [])  ([8b, 9a], [1b, 7d, 2a])
# 5   ([2a, 7d], [4b, 5b, 1c])  ([7a, 8d], [5d, 3b, 2c])
# 6   ([9b, 1b], [2b, 4b, 4d])  ([8c, 5b], [6b, 3c, 1c])
# 7   ([3b, 5b], [4d, 7b, 9b])                  ([], [])
# 8   ([8d, 8c], [4d, 9d, 7d])                  ([], [])
# 9   ([6c, 2d], [5b, 8d, 7b])                  ([], [])
# 10  ([1d, 4a], [9c, 3c, 8b])  ([2b, 5c], [1b, 8c, 1a])
# 11  ([6d, 4d], [9b, 8d, 3a])  ([6c, 4c], [7a, 4a, 9d])
# 12  ([5a, 9b], [1c, 3a, 6a])  ([8b, 5c], [1a, 2a, 7a])
# 13  ([1a, 4b], [9a, 8c, 3c])  ([8d, 2c], [3b, 9c, 8a])
# 14                  ([], [])  ([6a, 5c], [6c, 3a, 1d])
# 15                  ([], [])                  ([], [])
# 16  ([8b, 4b], [1b, 3c, 6b])  ([3d, 3b], [1d, 2b, 7b])
# 17                  ([], [])                  ([], [])
# 18  ([5d, 5a], [8a, 4c, 8d])  ([3a, 7b], [4b, 1c, 5b])
# 19  ([6a, 6c], [8b, 1b, 1d])  ([2a, 1c], [7a, 5d, 8c])
# 20  ([7c, 6b], [9c, 7a, 4d])  ([9b, 1c], [2c, 4b, 4c])
# 21  ([7c, 4c], [4a, 7a, 9c])  ([1a, 7b], [6c, 6b, 8b])
# 22  ([3b, 8b], [6b, 1a, 3d])                  ([], [])
# 23  ([8c, 6b], [1d, 2a, 7c])  ([4c, 9a], [9d, 8b, 3d])
# 24  ([5c, 4b], [8a, 9d, 3b])  ([4a, 6d], [5d, 8c, 7b])
# 25  ([8a, 1a], [5c, 6a, 9a])                  ([], [])
# 26  ([3b, 9d], [5a, 1c, 4d])  ([9b, 5c], [9c, 7d, 4a])
# 27  ([9a, 2c], [6d, 5c, 9c])  ([2d, 8b], [6b, 5a, 9b])
# 28                  ([], [])  ([4c, 7d], [7b, 5c, 8c])
# 29                  ([], [])  ([1a, 4d], [4a, 9d, 7a])
# ..                       ...                       ...
# 70  ([4c, 6b], [8b, 9d, 3d])  ([8c, 3b], [5b, 3a, 2c])
# 71                  ([], [])                  ([], [])
# 72                  ([], [])                  ([], [])
# 73                  ([], [])  ([4b, 6b], [4d, 7c, 9c])
# 74                  ([], [])  ([9c, 2d], [6b, 8d, 6c])
# 75                  ([], [])  ([7d, 7c], [9c, 8b, 3a])
# 76  ([2d, 8a], [5a, 4a, 1d])                  ([], [])
# 77  ([3a, 4d], [1c, 4b, 5b])  ([5c, 2a], [7c, 7a, 6a])
# 78  ([2c, 6b], [8d, 7b, 5b])                  ([], [])
# 79  ([8c, 9b], [6d, 8b, 6b])                  ([], [])
# 80  ([3a, 9d], [7d, 1c, 2c])  ([2b, 5c], [6a, 1a, 3d])
# 81  ([7c, 4a], [7a, 7b, 6c])                  ([], [])
# 82  ([8a, 5d], [7c, 1a, 2b])  ([7d, 4c], [3d, 9c, 8b])
# 83  ([6c, 3d], [4b, 9d, 7d])                  ([], [])
# 84  ([4c, 3d], [9c, 2d, 9b])  ([6d, 8c], [2a, 1b, 7c])
# 85                  ([], [])  ([7a, 8a], [3c, 2b, 5c])
# 86  ([9d, 1c], [9c, 6d, 5a])                  ([], [])
# 87  ([9b, 8a], [5b, 2c, 3b])                  ([], [])
# 88                  ([], [])                  ([], [])
# 89  ([8d, 8c], [4b, 5d, 1d])                  ([], [])
# 90                  ([], [])  ([2a, 9d], [8d, 5c, 7d])
# 91  ([1d, 2a], [3d, 8d, 9b])                  ([], [])
# 92  ([7d, 1d], [3d, 2a, 5d])  ([6d, 4b], [2c, 1a, 7a])
# 93  ([5b, 7c], [6d, 8d, 6c])  ([4a, 7d], [3d, 9a, 8a])
# 94  ([4a, 5a], [9c, 6a, 5b])                  ([], [])
# 95                  ([], [])  ([2c, 5a], [6c, 6d, 8d])
# 96                  ([], [])  ([2a, 8a], [8d, 1c, 1d])
# 97  ([6d, 2b], [7b, 7c, 6c])  ([7a, 5a], [4c, 3d, 3b])
# 98  ([4a, 7b], [5d, 6a, 9d])  ([3c, 5b], [2c, 2b, 6c])
# 99  ([9c, 9a], [1c, 8a, 1d])  ([6a, 9d], [8d, 7c, 5a])
#
#                      player3                   player4  \
# 0                   ([], [])  ([5c, 6c], [5b, 7a, 8a])
# 1   ([1a, 1b], [9c, 9b, 2c])                  ([], [])
# 2                   ([], [])  ([3a, 8b], [2c, 2d, 6d])
# 3   ([9d, 4c], [1a, 7d, 2d])  ([7a, 8c], [3b, 6d, 1d])
# 4                   ([], [])                  ([], [])
# 5   ([7b, 8b], [1a, 3a, 6b])  ([2d, 9a], [9c, 6a, 5a])
# 6                   ([], [])  ([7d, 8a], [5c, 8d, 7b])
# 7   ([7a, 1c], [9d, 6d, 5a])                  ([], [])
# 8   ([4a, 8a], [5a, 2a, 3a])  ([2d, 4b], [3b, 6a, 1c])
# 9                   ([], [])  ([4b, 8b], [5d, 3d, 2b])
# 10  ([6a, 3a], [8a, 4b, 8d])                  ([], [])
# 11  ([2b, 5c], [1b, 1c, 8c])  ([9c, 8b], [2d, 7d, 1a])
# 12  ([4d, 9c], [3d, 5d, 2b])                  ([], [])
# 13  ([7a, 5d], [7d, 4a, 9d])  ([4d, 6d], [7b, 2d, 1c])
# 14  ([3d, 3b], [8c, 7d, 5a])  ([8a, 1b], [7c, 1a, 2d])
# 15  ([9a, 2a], [4c, 8a, 8b])  ([6d, 1b], [4d, 3d, 3b])
# 16  ([5d, 5c], [4d, 7d, 9c])  ([8c, 6a], [4a, 1c, 5a])
# 17                  ([], [])                  ([], [])
# 18                  ([], [])  ([6a, 2b], [7d, 7c, 6b])
# 19  ([3c, 6b], [2b, 4a, 4c])  ([7c, 2d], [7b, 8a, 5b])
# 20                  ([], [])  ([3d, 3c], [5a, 7d, 8b])
# 21  ([5c, 2b], [4d, 4b, 2a])                  ([], [])
# 22                  ([], [])  ([7b, 1d], [9c, 5d, 6c])
# 23  ([6c, 5a], [2c, 4a, 4b])                  ([], [])
# 24  ([3d, 9c], [7d, 7c, 6b])  ([6c, 9a], [1c, 4c, 5b])
# 25  ([5b, 4a], [1c, 7c, 2b])                  ([], [])
# 26                  ([], [])  ([7b, 6c], [7c, 5b, 8a])
# 27  ([8c, 4d], [1b, 7d, 2a])                  ([], [])
# 28                  ([], [])                  ([], [])
# 29  ([6d, 2c], [3d, 3a, 4b])                  ([], [])
# ..                       ...                       ...
# 70                  ([], [])  ([2b, 4a], [7c, 7b, 6a])
# 71                  ([], [])                  ([], [])
# 72                  ([], [])                  ([], [])
# 73                  ([], [])  ([4a, 8b], [9a, 2d, 9b])
# 74                  ([], [])                  ([], [])
# 75  ([4c, 5b], [5a, 9d, 6b])  ([2b, 6a], [8a, 9a, 3b])
# 76  ([3c, 1c], [3b, 4d, 3a])                  ([], [])
# 77  ([9b, 1d], [4a, 8a, 8b])  ([3c, 3b], [2c, 2d, 6c])
# 78  ([9d, 4d], [8b, 7c, 5d])  ([8c, 4a], [2d, 7d, 1c])
# 79  ([1d, 3c], [9c, 3a, 8d])                  ([], [])
# 80                  ([], [])  ([2d, 5d], [5b, 1d, 4b])
# 81                  ([], [])  ([8d, 1b], [6a, 2d, 2c])
# 82                  ([], [])  ([1c, 9b], [1b, 4b, 5b])
# 83  ([8a, 1c], [8d, 7c, 5d])  ([5c, 2d], [6b, 8b, 6a])
# 84                  ([], [])                  ([], [])
# 85  ([4b, 2d], [1c, 1d, 8d])  ([2a, 3b], [6d, 8b, 6a])
# 86  ([4a, 7a], [4c, 4b, 2a])                  ([], [])
# 87  ([2d, 8d], [6d, 3c, 1c])                  ([], [])
# 88  ([1a, 7d], [3d, 9b, 8d])  ([1c, 4d], [2b, 2c, 6b])
# 89  ([6d, 8a], [2a, 3c, 5c])                  ([], [])
# 90                  ([], [])  ([5a, 1c], [2c, 6a, 2b])
# 91  ([5a, 2c], [1a, 3b, 6c])  ([7c, 6d], [4d, 9c, 7a])
# 92  ([9b, 9d], [2b, 3c, 5b])                  ([], [])
# 93  ([3c, 1b], [7a, 5d, 8c])                  ([], [])
# 94                  ([], [])  ([1b, 7d], [9b, 2d, 9a])
# 95  ([2d, 5c], [4d, 7b, 9c])  ([9d, 3c], [7c, 5d, 8c])
# 96  ([8c, 4d], [3c, 2b, 5c])  ([1a, 1b], [9d, 2c, 9b])
# 97  ([9b, 7d], [2a, 5c, 3a])                  ([], [])
# 98  ([4b, 5a], [8c, 6d, 6b])  ([1c, 8b], [9a, 2d, 9c])
# 99  ([6c, 7a], [5c, 4a, 1a])  ([4c, 4d], [5b, 9b, 6b])
#
#                      player5                   player6  \
# 0                   ([], [])                  ([], [])
# 1   ([7d, 3b], [7a, 9d, 4b])                  ([], [])
# 2   ([8a, 4c], [9b, 3b, 8d])                  ([], [])
# 3   ([5b, 9c], [1c, 7b, 2a])  ([8d, 2c], [3a, 1b, 6b])
# 4   ([5b, 1d], [7a, 6b, 7c])  ([4d, 4c], [9d, 8d, 3a])
# 5   ([8a, 6d], [9b, 4d, 7c])  ([3c, 2b], [6c, 1b, 3d])
# 6   ([9d, 7a], [6d, 9a, 5a])                  ([], [])
# 7                   ([], [])  ([3a, 7c], [8d, 6c, 6a])
# 8   ([9b, 9c], [5d, 8b, 7a])  ([1b, 9a], [6d, 1d, 3d])
# 9                   ([], [])  ([9a, 1a], [2a, 5c, 3a])
# 10  ([7a, 4d], [7d, 1c, 2c])  ([5d, 2a], [9b, 2d, 9a])
# 11  ([5d, 8a], [2a, 5a, 3c])  ([7c, 4b], [6a, 3d, 1d])
# 12  ([8c, 6b], [9d, 4b, 7b])  ([9a, 3c], [6d, 6c, 8a])
# 13                  ([], [])  ([3a, 2a], [6c, 8b, 6a])
# 14  ([4d, 9d], [4c, 2a, 4a])                  ([], [])
# 15                  ([], [])                  ([], [])
# 16                  ([], [])  ([6c, 9a], [2d, 3a, 5b])
# 17                  ([], [])  ([4d, 6a], [8c, 7a, 5b])
# 18                  ([], [])                  ([], [])
# 19                  ([], [])  ([8d, 9b], [4d, 3b, 3a])
# 20  ([8a, 9d], [1a, 4a, 5c])  ([8d, 5b], [2d, 6d, 2a])
# 21  ([3a, 1c], [8a, 9b, 3d])  ([9a, 7d], [3c, 6d, 1b])
# 22                  ([], [])  ([6a, 4a], [9b, 6d, 5b])
# 23  ([7a, 8d], [3a, 1c, 6a])  ([6d, 4d], [9c, 2b, 9b])
# 24                  ([], [])  ([1b, 2d], [5a, 2b, 3c])
# 25  ([7d, 4c], [1b, 1d, 8b])                  ([], [])
# 26  ([2d, 3d], [8b, 1d, 1b])                  ([], [])
# 27  ([5b, 6c], [4c, 3c, 3b])  ([3a, 9d], [8a, 1c, 1d])
# 28  ([8b, 5a], [6b, 3c, 1b])                  ([], [])
# 29  ([5b, 8b], [1c, 7d, 2a])                  ([], [])
# ..                       ...                       ...
# 70                  ([], [])  ([8a, 8d], [9b, 6c, 5d])
# 71  ([9a, 5c], [2a, 4c, 4b])                  ([], [])
# 72  ([1d, 8b], [2d, 3d, 5a])  ([6a, 7d], [3b, 2c, 5c])
# 73  ([3a, 7d], [6c, 2b, 2c])  ([1b, 8a], [8c, 5d, 7b])
# 74                  ([], [])                  ([], [])
# 75  ([7a, 3d], [1b, 5c, 4b])  ([6c, 8c], [5d, 1c, 4a])
# 76  ([9a, 2b], [7b, 8b, 5d])  ([9b, 4b], [5c, 2a, 3d])
# 77                  ([], [])                  ([], [])
# 78  ([3c, 9a], [2b, 7a, 1d])  ([6d, 6a], [3d, 4b, 3a])
# 79  ([2a, 5d], [6a, 7c, 7b])                  ([], [])
# 80                  ([], [])  ([8c, 5a], [6d, 8b, 6b])
# 81  ([8b, 2a], [5a, 2b, 3c])  ([8a, 6b], [4b, 9c, 7d])
# 82                  ([], [])                  ([], [])
# 83  ([4c, 2b], [2a, 5a, 3c])                  ([], [])
# 84  ([7b, 3b], [9d, 5d, 6b])  ([5c, 5b], [2b, 1c, 7d])
# 85  ([4c, 9b], [5a, 6c, 9d])                  ([], [])
# 86  ([7d, 7c], [3c, 8c, 9a])                  ([], [])
# 87  ([6c, 4a], [8c, 5a, 7a])  ([9a, 4c], [3d, 5d, 2a])
# 88                  ([], [])  ([3b, 6d], [6c, 5d, 9a])
# 89                  ([], [])                  ([], [])
# 90  ([1b, 3c], [8b, 9a, 3b])  ([5d, 6d], [2d, 9c, 9b])
# 91                  ([], [])  ([3a, 1b], [8c, 5c, 7b])
# 92  ([4d, 6b], [7b, 6a, 7c])  ([8d, 9a], [1c, 5c, 4c])
# 93                  ([], [])  ([9b, 7b], [3b, 1a, 6b])
# 94  ([2c, 8a], [8d, 3d, 9d])  ([2a, 2b], [4c, 1c, 5c])
# 95  ([4b, 2a], [8b, 3b, 9a])                  ([], [])
# 96                  ([], [])                  ([], [])
# 97  ([2d, 1c], [3c, 9c, 8d])                  ([], [])
# 98  ([2a, 3b], [3d, 3a, 4d])  ([9b, 5c], [1b, 8a, 1d])
# 99  ([3c, 3d], [2a, 2b, 6d])  ([3a, 4b], [8b, 5d, 7b])
#
#                      player7   zhuang
# 0                   ([], [])  player1
# 1                   ([], [])  player1
# 2   ([1a, 2a], [8c, 6c, 6a])  player5
# 3   ([3c, 2b], [8b, 6a, 6c])  player1
# 4   ([2d, 7b], [5d, 9b, 6c])  player6
# 5   ([4c, 8c], [5c, 4a, 1d])  player6
# 6   ([2a, 7c], [3d, 4c, 3b])  player6
# 7   ([8b, 2a], [1a, 2c, 7d])  player1
# 8   ([5c, 6c], [2b, 1a, 7b])  player7
# 9   ([1c, 2c], [7c, 4a, 9b])  player6
# 10                  ([], [])  player6
# 11  ([6b, 7b], [2c, 3b, 5b])  player6
# 12  ([2d, 7d], [1b, 5b, 4c])  player2
# 13  ([9b, 3d], [1b, 4c, 5a])  player2
# 14                  ([], [])  player4
# 15                  ([], [])  player4
# 16  ([7c, 1a], [9b, 9d, 2a])  player4
# 17                  ([], [])  player3
# 18                  ([], [])  player6
# 19                  ([], [])  player2
# 20  ([9a, 5d], [3b, 1b, 6c])  player2
# 21  ([1d, 9d], [2d, 5b, 3b])  player2
# 22  ([9a, 4b], [8a, 5a, 7a])  player7
# 23  ([5b, 1a], [2d, 3b, 5d])  player6
# 24  ([7a, 9b], [8d, 1a, 1d])  player6
# 25  ([3c, 7a], [9d, 6b, 5d])  player2
# 26  ([4c, 1a], [5d, 6d, 9a])  player7
# 27  ([8d, 4b], [3d, 6a, 1a])  player7
# 28  ([8a, 4d], [6a, 2d, 2c])  player2
# 29  ([7b, 7c], [9a, 2d, 9b])  player2
# ..                       ...      ...
# 70  ([1b, 1c], [4d, 2d, 4b])  player5
# 71  ([7a, 6c], [1b, 4d, 5a])  player1
# 72  ([9c, 3a], [6b, 6d, 8d])  player1
# 73  ([4c, 7a], [3c, 2a, 5a])  player1
# 74                  ([], [])  player5
# 75                  ([], [])  player5
# 76                  ([], [])  player5
# 77  ([1b, 7b], [6b, 8d, 6d])  player1
# 78  ([6c, 8a], [2a, 5a, 3b])  player3
# 79  ([1c, 4c], [3d, 8a, 9d])  player3
# 80  ([3c, 8d], [4d, 4c, 2a])  player3
# 81  ([9b, 8c], [4d, 3a, 3d])  player3
# 82  ([3a, 9d], [4d, 4a, 2c])  player5
# 83  ([4d, 4a], [8c, 9c, 3a])  player4
# 84  ([4a, 9a], [1a, 1d, 8a])  player4
# 85                  ([], [])  player6
# 86  ([5c, 6c], [5d, 3d, 2c])  player6
# 87  ([2b, 1b], [8b, 5c, 7c])  player1
# 88  ([4c, 7b], [8c, 7c, 5c])  player5
# 89  ([5a, 1c], [1a, 7d, 2d])  player5
# 90  ([1a, 7b], [1d, 4b, 5b])  player5
# 91  ([9d, 7d], [6a, 3c, 1c])  player5
# 92  ([6c, 3a], [9c, 8a, 3b])  player5
# 93  ([2b, 1c], [5a, 6a, 9c])  player2
# 94                  ([], [])  player2
# 95  ([2b, 5b], [6b, 1d, 3a])  player5
# 96                  ([], [])  player5
# 97                  ([], [])  player2
# 98                  ([], [])  player2
# 99                  ([], [])  player2
#
# [100 rows x 8 columns]

# %%
temp_xian,zhuang,point_z
# Out:
# ({'player1': 8,
#   'player3': 3,
#   'player4': 8,
#   'player5': 6,
#   'player6': 7,
#   'player7': 0},
#  'player2',
#  5)
